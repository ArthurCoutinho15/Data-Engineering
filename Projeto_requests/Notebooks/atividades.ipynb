# %% [markdown]
# Para praticar o conteúdo aprendido no decorrer dessa aula e também aprender novos, vamos realizar um desafio prático utilizando a biblioteca Requests e a API do GitHub.
#
# Faça uma requisição GET à API do Github para obter as informações do perfil de um usuário específico. Para isso, utilize a biblioteca Requests do Python e a URL https://api.github.com/users/{username}, substituindo {username} pelo nome de usuário desejado.
#
# Com o objeto response retornado pela requisição, imprima na tela as seguintes informações sobre a requisição:
#
# status code da requisição, para analisar se foi bem sucedida ou não;
# conteúdo da requisição, para conferir se os dados de usuário vieram corretamente;
# URL da requisição feita, para garantir que a url utilizada na requisição foi a correta.
# Após conferir isso, analise novamente o conteúdo retornado pela requisição e imprima na tela apenas as seguintes informações sobre a pessoa usuária em questão:
#
# Nome
# Nome de usuário
# Número de repositórios públicos
# Data de criação da conta no GitHub
# Dica: Para selecionar essas informações específicas, você pode visualizar o conteúdo da requisição no formato JSON e fazer a seleção das chaves que possuem as informações desejadas.

# %%
import requests

# %%
r = requests.get('https://api.github.com/users/ArthurCoutinho15')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"login":"ArthurCoutinho15","id":125709418,"node_id":"U_kgDOB34sag","avatar_url":"https://avatars.githubusercontent.com/u/125709418?v=4","gravatar_id":"","url":"https://api.github.com/users/ArthurCoutinho15","html_url":"https://github.com/ArthurCoutinho15","followers_url":"https://api.github.com/users/ArthurCoutinho15/followers","following_url":"https://api.github.com/users/ArthurCoutinho15/following{/other_user}","gists_url":"https://api.github.com/users/ArthurCoutinho15/gists{/gist_id}","starred_url":"https://api.github.com/users/ArthurCoutinho15/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ArthurCoutinho15/subscriptions","organizations_url":"https://api.github.com/users/ArthurCoutinho15/orgs","repos_url":"https://api.github.com/users/ArthurCoutinho15/repos","events_url":"https://api.github.com/users/ArthurCoutinho15/events{/privacy}","received_events_url":"https://api.github.com/users/ArthurCoutinho15/received_events","type":"User","site_admin":false,"name":"Arthur Coutinho ","company":"Banco Mercantil","blog":"","location":"Belo Horizonte - Minas Gerais - Brasil","email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":41,"public_gists":0,"followers":0,"following":3,"created_at":"2023-02-18T00:35:40Z","updated_at":"2024-05-17T22:19:56Z"}'

# %%
r.url
# Out:
# 'https://api.github.com/users/ArthurCoutinho15'

# %%
r.json()['company']
# Out:
# 'Banco Mercantil'

# %% [markdown]
# ----

# %% [markdown]
# Para praticar o conteúdo aprendido no decorrer dessa aula e também aprender novos, vamos realizar um desafio prático utilizando a biblioteca Requests e a API do GitHub.
#
# Dessa vez, nossa tarefa é extrair os dados sobre os seguidores da conta da Amazon no GitHub. Para fazermos isso, vamos utilizar como referência a seguinte documentação: List followers of a user.
#
# Analisando a documentação, nós chegamos ao seguinte código inicial:

# %%
import requests

access_token = 'token removido para commit'
headers = {'Authorization': 'Bearer' + access_token,
          'X-GitHub-Api-Version': '2022-11-28'}

username = 'amzn'
url = f"https://api.github.com/users/{username}/followers"

response = requests.get(url, headers=headers)
followers = response.json()

url
# Out:
# 'https://api.github.com/users/amzn/followers'

# %% [markdown]
# No entanto, ao conferir o tamanho da lista followers, utilizando a função len(followers), notamos que ela possuía apenas os dados de 30 seguidores da conta do GitHub da Amazon. A conta tem muito mais de 30 seguidores, mas eles estão separados em diferentes páginas, e justamente por isso, ao conferirmos o tamanho da lista, o retorno foi 30.
#
# Sendo assim, para conseguirmos extrair os dados de todos os seguidores, vamos precisar melhorar o nosso código e implementar o processo de paginação.
#
# Durante essa etapa, devemos nos atentar a alguns detalhes:
#
# criar uma lista vazia chamada followers_list para armazenar as informações sobre os seguidores;
#
# utilizar um laço para iterar e extrair os dados dos seguidores existentes em cada uma das páginas (dica: caso você não tenha conhecimento de quantas páginas com seguidores existem, pesquise como utilizar o laço While True do Python);
#
# acrescentar o parâmetro "page" na url, alterando o valor dele a cada iteração do laço que estiver sendo usado para paginação (lembre-se que a numeração das páginas sempre começam a partir do número 1);
#
# enviar o token e a versão da API para o parâmetro headers no momento de fazer a requisição GET.

# %%
len(response.json())
# Out:
# 30

# %%
followers_list = []

for page_num in range(1,31):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        followers_list.append(response.json())
    except:
        followers_list.append(None)

# %%
len(followers_list[-1])
# Out:
# 30

# %%
import requests

username = 'amzn'
url = f"https://api.github.com/users/{username}/followers"

# definindo o token e a versão da API
access_token = 'seu_token'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

page = 1
followers_list = []

while True: 

    # faz a requisição 
    url_page = f'{url}?page={page}'
    response = requests.get(url_page, headers=headers)

    # converte a resposta para um objeto JSON
    followers = response.json()

    # caso a lista esteja vazia, podemos sair do laço pois todos os dados foram extraidos
    if len(followers)==0:
        break

    # adicionando os seguidores a lista
    followers_list.append(followers)

    # incrementa o valor de 'page' para a próxima requisição
    page += 1

# %% [markdown]
# Para praticar o conteúdo aprendido no decorrer dessa aula e também aprender novos, vamos realizar um desafio prático utilizando a biblioteca Pandas e os dados da API do GitHub.
#
# No desafio da aula 2 nós extraímos os dados de todos os seguidores da conta do Github da Amazon e armazenamos eles na lista "followers_list". Considerando isso, nossa tarefa agora é aplicar as transformações necessárias nos dados armazenados na lista followers_list para selecionarmos apenas o nome de usuário de cada seguidor.
#
# Para concluirmos essa tarefa é importante:
#
# entender como os dados dos seguidores estão estruturados na lista;
# armazenar o nome de usuário de cada seguidor em uma lista;
# conferir o tamanho da lista de nomes de usuário de seguidores para ter certeza que é igual ao número de seguidores apresentados no Github;
# estruturar os dados em um DataFrame e salvá-los em CSV.

# %%
followers_list[1]
# Out:
# [{'login': 'DaemonCahill',
#   'id': 438181,
#   'node_id': 'MDQ6VXNlcjQzODE4MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/438181?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/DaemonCahill',
#   'html_url': 'https://github.com/DaemonCahill',
#   'followers_url': 'https://api.github.com/users/DaemonCahill/followers',
#   'following_url': 'https://api.github.com/users/DaemonCahill/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/DaemonCahill/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/DaemonCahill/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/DaemonCahill/subscriptions',
#   'organizations_url': 'https://api.github.com/users/DaemonCahill/orgs',
#   'repos_url': 'https://api.github.com/users/DaemonCahill/repos',
#   'events_url': 'https://api.github.com/users/DaemonCahill/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/DaemonCahill/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Cambera',
#   'id': 491091,
#   'node_id': 'MDQ6VXNlcjQ5MTA5MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/491091?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Cambera',
#   'html_url': 'https://github.com/Cambera',
#   'followers_url': 'https://api.github.com/users/Cambera/followers',
#   'following_url': 'https://api.github.com/users/Cambera/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Cambera/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Cambera/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Cambera/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Cambera/orgs',
#   'repos_url': 'https://api.github.com/users/Cambera/repos',
#   'events_url': 'https://api.github.com/users/Cambera/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Cambera/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'riyadparvez',
#   'id': 494783,
#   'node_id': 'MDQ6VXNlcjQ5NDc4Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/494783?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/riyadparvez',
#   'html_url': 'https://github.com/riyadparvez',
#   'followers_url': 'https://api.github.com/users/riyadparvez/followers',
#   'following_url': 'https://api.github.com/users/riyadparvez/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/riyadparvez/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/riyadparvez/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/riyadparvez/subscriptions',
#   'organizations_url': 'https://api.github.com/users/riyadparvez/orgs',
#   'repos_url': 'https://api.github.com/users/riyadparvez/repos',
#   'events_url': 'https://api.github.com/users/riyadparvez/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/riyadparvez/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'nattfodd',
#   'id': 540337,
#   'node_id': 'MDQ6VXNlcjU0MDMzNw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/540337?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nattfodd',
#   'html_url': 'https://github.com/nattfodd',
#   'followers_url': 'https://api.github.com/users/nattfodd/followers',
#   'following_url': 'https://api.github.com/users/nattfodd/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/nattfodd/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/nattfodd/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/nattfodd/subscriptions',
#   'organizations_url': 'https://api.github.com/users/nattfodd/orgs',
#   'repos_url': 'https://api.github.com/users/nattfodd/repos',
#   'events_url': 'https://api.github.com/users/nattfodd/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/nattfodd/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mitaka',
#   'id': 548822,
#   'node_id': 'MDQ6VXNlcjU0ODgyMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/548822?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mitaka',
#   'html_url': 'https://github.com/mitaka',
#   'followers_url': 'https://api.github.com/users/mitaka/followers',
#   'following_url': 'https://api.github.com/users/mitaka/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mitaka/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mitaka/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mitaka/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mitaka/orgs',
#   'repos_url': 'https://api.github.com/users/mitaka/repos',
#   'events_url': 'https://api.github.com/users/mitaka/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mitaka/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ZhangYunfang',
#   'id': 586120,
#   'node_id': 'MDQ6VXNlcjU4NjEyMA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/586120?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ZhangYunfang',
#   'html_url': 'https://github.com/ZhangYunfang',
#   'followers_url': 'https://api.github.com/users/ZhangYunfang/followers',
#   'following_url': 'https://api.github.com/users/ZhangYunfang/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ZhangYunfang/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ZhangYunfang/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ZhangYunfang/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ZhangYunfang/orgs',
#   'repos_url': 'https://api.github.com/users/ZhangYunfang/repos',
#   'events_url': 'https://api.github.com/users/ZhangYunfang/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ZhangYunfang/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'temosy',
#   'id': 587726,
#   'node_id': 'MDQ6VXNlcjU4NzcyNg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/587726?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/temosy',
#   'html_url': 'https://github.com/temosy',
#   'followers_url': 'https://api.github.com/users/temosy/followers',
#   'following_url': 'https://api.github.com/users/temosy/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/temosy/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/temosy/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/temosy/subscriptions',
#   'organizations_url': 'https://api.github.com/users/temosy/orgs',
#   'repos_url': 'https://api.github.com/users/temosy/repos',
#   'events_url': 'https://api.github.com/users/temosy/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/temosy/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'threadstonesecure',
#   'id': 644476,
#   'node_id': 'MDQ6VXNlcjY0NDQ3Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/644476?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/threadstonesecure',
#   'html_url': 'https://github.com/threadstonesecure',
#   'followers_url': 'https://api.github.com/users/threadstonesecure/followers',
#   'following_url': 'https://api.github.com/users/threadstonesecure/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/threadstonesecure/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/threadstonesecure/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/threadstonesecure/subscriptions',
#   'organizations_url': 'https://api.github.com/users/threadstonesecure/orgs',
#   'repos_url': 'https://api.github.com/users/threadstonesecure/repos',
#   'events_url': 'https://api.github.com/users/threadstonesecure/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/threadstonesecure/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'manuelhunziker',
#   'id': 655369,
#   'node_id': 'MDQ6VXNlcjY1NTM2OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/655369?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/manuelhunziker',
#   'html_url': 'https://github.com/manuelhunziker',
#   'followers_url': 'https://api.github.com/users/manuelhunziker/followers',
#   'following_url': 'https://api.github.com/users/manuelhunziker/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/manuelhunziker/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/manuelhunziker/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/manuelhunziker/subscriptions',
#   'organizations_url': 'https://api.github.com/users/manuelhunziker/orgs',
#   'repos_url': 'https://api.github.com/users/manuelhunziker/repos',
#   'events_url': 'https://api.github.com/users/manuelhunziker/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/manuelhunziker/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ambagasdowa',
#   'id': 661086,
#   'node_id': 'MDQ6VXNlcjY2MTA4Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/661086?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ambagasdowa',
#   'html_url': 'https://github.com/ambagasdowa',
#   'followers_url': 'https://api.github.com/users/ambagasdowa/followers',
#   'following_url': 'https://api.github.com/users/ambagasdowa/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ambagasdowa/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ambagasdowa/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ambagasdowa/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ambagasdowa/orgs',
#   'repos_url': 'https://api.github.com/users/ambagasdowa/repos',
#   'events_url': 'https://api.github.com/users/ambagasdowa/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ambagasdowa/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'pedro-lima',
#   'id': 707395,
#   'node_id': 'MDQ6VXNlcjcwNzM5NQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/707395?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pedro-lima',
#   'html_url': 'https://github.com/pedro-lima',
#   'followers_url': 'https://api.github.com/users/pedro-lima/followers',
#   'following_url': 'https://api.github.com/users/pedro-lima/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pedro-lima/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/pedro-lima/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pedro-lima/subscriptions',
#   'organizations_url': 'https://api.github.com/users/pedro-lima/orgs',
#   'repos_url': 'https://api.github.com/users/pedro-lima/repos',
#   'events_url': 'https://api.github.com/users/pedro-lima/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/pedro-lima/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'alexharvey',
#   'id': 722253,
#   'node_id': 'MDQ6VXNlcjcyMjI1Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/722253?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alexharvey',
#   'html_url': 'https://github.com/alexharvey',
#   'followers_url': 'https://api.github.com/users/alexharvey/followers',
#   'following_url': 'https://api.github.com/users/alexharvey/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/alexharvey/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/alexharvey/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/alexharvey/subscriptions',
#   'organizations_url': 'https://api.github.com/users/alexharvey/orgs',
#   'repos_url': 'https://api.github.com/users/alexharvey/repos',
#   'events_url': 'https://api.github.com/users/alexharvey/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/alexharvey/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'josh-fisher',
#   'id': 735570,
#   'node_id': 'MDQ6VXNlcjczNTU3MA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/735570?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/josh-fisher',
#   'html_url': 'https://github.com/josh-fisher',
#   'followers_url': 'https://api.github.com/users/josh-fisher/followers',
#   'following_url': 'https://api.github.com/users/josh-fisher/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/josh-fisher/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/josh-fisher/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/josh-fisher/subscriptions',
#   'organizations_url': 'https://api.github.com/users/josh-fisher/orgs',
#   'repos_url': 'https://api.github.com/users/josh-fisher/repos',
#   'events_url': 'https://api.github.com/users/josh-fisher/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/josh-fisher/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'kumarlokesh',
#   'id': 742592,
#   'node_id': 'MDQ6VXNlcjc0MjU5Mg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/742592?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kumarlokesh',
#   'html_url': 'https://github.com/kumarlokesh',
#   'followers_url': 'https://api.github.com/users/kumarlokesh/followers',
#   'following_url': 'https://api.github.com/users/kumarlokesh/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kumarlokesh/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/kumarlokesh/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kumarlokesh/subscriptions',
#   'organizations_url': 'https://api.github.com/users/kumarlokesh/orgs',
#   'repos_url': 'https://api.github.com/users/kumarlokesh/repos',
#   'events_url': 'https://api.github.com/users/kumarlokesh/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/kumarlokesh/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'subidit',
#   'id': 747151,
#   'node_id': 'MDQ6VXNlcjc0NzE1MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/747151?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/subidit',
#   'html_url': 'https://github.com/subidit',
#   'followers_url': 'https://api.github.com/users/subidit/followers',
#   'following_url': 'https://api.github.com/users/subidit/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/subidit/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/subidit/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/subidit/subscriptions',
#   'organizations_url': 'https://api.github.com/users/subidit/orgs',
#   'repos_url': 'https://api.github.com/users/subidit/repos',
#   'events_url': 'https://api.github.com/users/subidit/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/subidit/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'pdevenraj',
#   'id': 761450,
#   'node_id': 'MDQ6VXNlcjc2MTQ1MA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/761450?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pdevenraj',
#   'html_url': 'https://github.com/pdevenraj',
#   'followers_url': 'https://api.github.com/users/pdevenraj/followers',
#   'following_url': 'https://api.github.com/users/pdevenraj/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pdevenraj/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/pdevenraj/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pdevenraj/subscriptions',
#   'organizations_url': 'https://api.github.com/users/pdevenraj/orgs',
#   'repos_url': 'https://api.github.com/users/pdevenraj/repos',
#   'events_url': 'https://api.github.com/users/pdevenraj/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/pdevenraj/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'nerandell',
#   'id': 820105,
#   'node_id': 'MDQ6VXNlcjgyMDEwNQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/820105?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nerandell',
#   'html_url': 'https://github.com/nerandell',
#   'followers_url': 'https://api.github.com/users/nerandell/followers',
#   'following_url': 'https://api.github.com/users/nerandell/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/nerandell/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/nerandell/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/nerandell/subscriptions',
#   'organizations_url': 'https://api.github.com/users/nerandell/orgs',
#   'repos_url': 'https://api.github.com/users/nerandell/repos',
#   'events_url': 'https://api.github.com/users/nerandell/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/nerandell/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'raghuboosetty',
#   'id': 853315,
#   'node_id': 'MDQ6VXNlcjg1MzMxNQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/853315?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/raghuboosetty',
#   'html_url': 'https://github.com/raghuboosetty',
#   'followers_url': 'https://api.github.com/users/raghuboosetty/followers',
#   'following_url': 'https://api.github.com/users/raghuboosetty/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/raghuboosetty/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/raghuboosetty/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/raghuboosetty/subscriptions',
#   'organizations_url': 'https://api.github.com/users/raghuboosetty/orgs',
#   'repos_url': 'https://api.github.com/users/raghuboosetty/repos',
#   'events_url': 'https://api.github.com/users/raghuboosetty/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/raghuboosetty/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'tdmalone',
#   'id': 900469,
#   'node_id': 'MDQ6VXNlcjkwMDQ2OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/900469?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tdmalone',
#   'html_url': 'https://github.com/tdmalone',
#   'followers_url': 'https://api.github.com/users/tdmalone/followers',
#   'following_url': 'https://api.github.com/users/tdmalone/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/tdmalone/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/tdmalone/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/tdmalone/subscriptions',
#   'organizations_url': 'https://api.github.com/users/tdmalone/orgs',
#   'repos_url': 'https://api.github.com/users/tdmalone/repos',
#   'events_url': 'https://api.github.com/users/tdmalone/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/tdmalone/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': '34code',
#   'id': 930787,
#   'node_id': 'MDQ6VXNlcjkzMDc4Nw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/930787?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/34code',
#   'html_url': 'https://github.com/34code',
#   'followers_url': 'https://api.github.com/users/34code/followers',
#   'following_url': 'https://api.github.com/users/34code/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/34code/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/34code/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/34code/subscriptions',
#   'organizations_url': 'https://api.github.com/users/34code/orgs',
#   'repos_url': 'https://api.github.com/users/34code/repos',
#   'events_url': 'https://api.github.com/users/34code/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/34code/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'burib',
#   'id': 956227,
#   'node_id': 'MDQ6VXNlcjk1NjIyNw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/956227?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/burib',
#   'html_url': 'https://github.com/burib',
#   'followers_url': 'https://api.github.com/users/burib/followers',
#   'following_url': 'https://api.github.com/users/burib/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/burib/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/burib/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/burib/subscriptions',
#   'organizations_url': 'https://api.github.com/users/burib/orgs',
#   'repos_url': 'https://api.github.com/users/burib/repos',
#   'events_url': 'https://api.github.com/users/burib/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/burib/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'whn09',
#   'id': 964527,
#   'node_id': 'MDQ6VXNlcjk2NDUyNw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/964527?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/whn09',
#   'html_url': 'https://github.com/whn09',
#   'followers_url': 'https://api.github.com/users/whn09/followers',
#   'following_url': 'https://api.github.com/users/whn09/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/whn09/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/whn09/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/whn09/subscriptions',
#   'organizations_url': 'https://api.github.com/users/whn09/orgs',
#   'repos_url': 'https://api.github.com/users/whn09/repos',
#   'events_url': 'https://api.github.com/users/whn09/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/whn09/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'bobbyearl',
#   'id': 971639,
#   'node_id': 'MDQ6VXNlcjk3MTYzOQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/971639?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/bobbyearl',
#   'html_url': 'https://github.com/bobbyearl',
#   'followers_url': 'https://api.github.com/users/bobbyearl/followers',
#   'following_url': 'https://api.github.com/users/bobbyearl/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/bobbyearl/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/bobbyearl/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/bobbyearl/subscriptions',
#   'organizations_url': 'https://api.github.com/users/bobbyearl/orgs',
#   'repos_url': 'https://api.github.com/users/bobbyearl/repos',
#   'events_url': 'https://api.github.com/users/bobbyearl/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/bobbyearl/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'alishir',
#   'id': 978306,
#   'node_id': 'MDQ6VXNlcjk3ODMwNg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/978306?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alishir',
#   'html_url': 'https://github.com/alishir',
#   'followers_url': 'https://api.github.com/users/alishir/followers',
#   'following_url': 'https://api.github.com/users/alishir/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/alishir/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/alishir/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/alishir/subscriptions',
#   'organizations_url': 'https://api.github.com/users/alishir/orgs',
#   'repos_url': 'https://api.github.com/users/alishir/repos',
#   'events_url': 'https://api.github.com/users/alishir/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/alishir/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ahlfors',
#   'id': 1074291,
#   'node_id': 'MDQ6VXNlcjEwNzQyOTE=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1074291?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ahlfors',
#   'html_url': 'https://github.com/ahlfors',
#   'followers_url': 'https://api.github.com/users/ahlfors/followers',
#   'following_url': 'https://api.github.com/users/ahlfors/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ahlfors/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ahlfors/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ahlfors/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ahlfors/orgs',
#   'repos_url': 'https://api.github.com/users/ahlfors/repos',
#   'events_url': 'https://api.github.com/users/ahlfors/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ahlfors/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'bsrz',
#   'id': 1077441,
#   'node_id': 'MDQ6VXNlcjEwNzc0NDE=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1077441?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/bsrz',
#   'html_url': 'https://github.com/bsrz',
#   'followers_url': 'https://api.github.com/users/bsrz/followers',
#   'following_url': 'https://api.github.com/users/bsrz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/bsrz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/bsrz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/bsrz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/bsrz/orgs',
#   'repos_url': 'https://api.github.com/users/bsrz/repos',
#   'events_url': 'https://api.github.com/users/bsrz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/bsrz/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mailmahee',
#   'id': 1077762,
#   'node_id': 'MDQ6VXNlcjEwNzc3NjI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1077762?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mailmahee',
#   'html_url': 'https://github.com/mailmahee',
#   'followers_url': 'https://api.github.com/users/mailmahee/followers',
#   'following_url': 'https://api.github.com/users/mailmahee/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mailmahee/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mailmahee/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mailmahee/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mailmahee/orgs',
#   'repos_url': 'https://api.github.com/users/mailmahee/repos',
#   'events_url': 'https://api.github.com/users/mailmahee/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mailmahee/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mihkels',
#   'id': 1080953,
#   'node_id': 'MDQ6VXNlcjEwODA5NTM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1080953?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mihkels',
#   'html_url': 'https://github.com/mihkels',
#   'followers_url': 'https://api.github.com/users/mihkels/followers',
#   'following_url': 'https://api.github.com/users/mihkels/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mihkels/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mihkels/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mihkels/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mihkels/orgs',
#   'repos_url': 'https://api.github.com/users/mihkels/repos',
#   'events_url': 'https://api.github.com/users/mihkels/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mihkels/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'daefresh',
#   'id': 1081154,
#   'node_id': 'MDQ6VXNlcjEwODExNTQ=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1081154?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/daefresh',
#   'html_url': 'https://github.com/daefresh',
#   'followers_url': 'https://api.github.com/users/daefresh/followers',
#   'following_url': 'https://api.github.com/users/daefresh/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/daefresh/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/daefresh/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/daefresh/subscriptions',
#   'organizations_url': 'https://api.github.com/users/daefresh/orgs',
#   'repos_url': 'https://api.github.com/users/daefresh/repos',
#   'events_url': 'https://api.github.com/users/daefresh/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/daefresh/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'dofstar',
#   'id': 1088442,
#   'node_id': 'MDQ6VXNlcjEwODg0NDI=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1088442?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dofstar',
#   'html_url': 'https://github.com/dofstar',
#   'followers_url': 'https://api.github.com/users/dofstar/followers',
#   'following_url': 'https://api.github.com/users/dofstar/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dofstar/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dofstar/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dofstar/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dofstar/orgs',
#   'repos_url': 'https://api.github.com/users/dofstar/repos',
#   'events_url': 'https://api.github.com/users/dofstar/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dofstar/received_events',
#   'type': 'User',
#   'site_admin': False}]

# %%
seguidores = []
for page in followers_list:
    for followers in page:
        seguidores.append(followers['login'])

# %%
seguidores
# Out:
# ['tkersey',
#  'njonsson',
#  'bangpound',
#  'koconder',
#  'Rud5G',
#  'mlsj1',
#  'syug',
#  'esneko',
#  'neopunisher',
#  'jazzwang',
#  'begoon',
#  'fly51fly',
#  'fallenpegasus',
#  'fribeiro1',
#  'brase',
#  'chchrist',
#  'massimoselvi',
#  'ScottJWalter',
#  'adeelahmad',
#  'mindcrime',
#  'informaticadiaz',
#  'MarceloNascimento',
#  'dmsbilas',
#  'thimslugga',
#  'leecardona',
#  'shyuan',
#  'nara',
#  'openam',
#  'semsphy',
#  'srp19',
#  'DaemonCahill',
#  'Cambera',
#  'riyadparvez',
#  'nattfodd',
#  'mitaka',
#  'ZhangYunfang',
#  'temosy',
#  'threadstonesecure',
#  'manuelhunziker',
#  'ambagasdowa',
#  'pedro-lima',
#  'alexharvey',
#  'josh-fisher',
#  'kumarlokesh',
#  'subidit',
#  'pdevenraj',
#  'nerandell',
#  'raghuboosetty',
#  'tdmalone',
#  '34code',
#  'burib',
#  'whn09',
#  'bobbyearl',
#  'alishir',
#  'ahlfors',
#  'bsrz',
#  'mailmahee',
#  'mihkels',
#  'daefresh',
#  'dofstar',
#  'codee',
#  'LisaDelaney',
#  'EdZava',
#  'pmanolak',
#  'kistasi',
#  'firebitsbr',
#  'glaucodiogo',
#  'manjunathd',
#  'afonsoalban',
#  'rsaa',
#  'hvn0413',
#  'duxing2007',
#  'ste93cry',
#  'terran1942',
#  'itanoss',
#  'thesobercoder',
#  'bygbyron3',
#  'rickymaciel',
#  'KevinGimbel',
#  'zsp0817',
#  'konamo',
#  'voldyman',
#  'golf-x',
#  'alexjennings',
#  'somaditya',
#  'apjowen',
#  'usui-tk',
#  'dengqixing',
#  'Davi-He',
#  'godsoul',
#  'kumar-nitish',
#  'snoop0x7b',
#  'PandaBlessing',
#  'andyuls',
#  'juanjoruiz2109',
#  'mangualero',
#  'haydenthai',
#  'proverbs53',
#  'Rajivhost',
#  'universewrld',
#  'dpapageo',
#  'HJiefeng',
#  'kkpan11',
#  'plumcube',
#  'magigo',
#  'ahmadfaizalbh',
#  'flukebox',
#  'jakebrinkmann',
#  'simar1998',
#  'CheeseTurtle',
#  'AAbasinejad',
#  'virtuoushub',
#  'huamichaelchen',
#  'mumblepins',
#  'b3nkos',
#  'bretdarby',
#  'srinitude',
#  'the-watchmaker',
#  'codinggooner',
#  'kimpenguin',
#  'weisberg',
#  'ace-coder',
#  'infinitedreams9586',
#  'tusharsoni08',
#  'hoansgithub',
#  'schallerala',
#  'alexxyjiang',
#  'star-fx',
#  'amavlyanov',
#  'garciparedes',
#  'keshabb',
#  's0nlxaftrsh0ck',
#  'darasat',
#  'mklemann-com',
#  'tiloyi',
#  'roykalony',
#  'zhangxiangdong',
#  'thomasdalbert',
#  'LavenderDaisy',
#  'edisona',
#  'Steven-Acomb',
#  'kevcooper',
#  'jodavaho',
#  'side9show',
#  'teeksingh',
#  'kevingrondin',
#  'koyashiro',
#  'unlitdev',
#  'well1791',
#  'mleziva',
#  'ajian005',
#  'ykaidashov',
#  'anand-b',
#  'xGreat',
#  'MatterhornProject',
#  'tolgabuyuktanir',
#  'cash2059',
#  'rajabalaji-mp',
#  'vedamj01',
#  'jafferlin',
#  'yixiuhua',
#  'rodazuero',
#  'JustCallMe-AK',
#  'henriquerick',
#  'Wyvernslay3r',
#  'gabrlyg',
#  'paulosiciliano',
#  'martinvaldivia',
#  'rdczhby',
#  'mys328',
#  'andrey-berenda',
#  'sinhang',
#  'Pal3love',
#  'Lakshmiaddepalli',
#  'mohamed-abdelsattar92',
#  'rawer886',
#  'jathurchan',
#  'thanhcsf',
#  'junaid109',
#  'roykhoury',
#  'bafeiyu',
#  'Ylmzef',
#  'anlexN',
#  'Janujan',
#  'fwblcz',
#  'djinl520',
#  'protyay',
#  'selfishprimate',
#  'Mwalthery',
#  'GregAllenSmith',
#  'zgover',
#  'avestura',
#  'aspindle',
#  'pqrsooo',
#  'evanshrestha',
#  'bos-hieu',
#  'hanautoparts4u',
#  'sonimonish00',
#  'ljesparis',
#  'imvikramn',
#  'massivelivefun',
#  'garrettrh',
#  'adanone',
#  'ghishadow',
#  'shower1986',
#  'mseld',
#  'JasonYe88',
#  'seshurajup',
#  'xiaopizi19',
#  'pelamlio',
#  'Asavarkhul',
#  'ajay340',
#  'custadian',
#  'KlwntSingh',
#  'FelixFeliciant',
#  'learnerzhang',
#  'gamedebug',
#  'jonathanarodr',
#  'osama-ahmed',
#  'nir-zilberman',
#  'changyongyong',
#  'bigDP',
#  'WajahatSiddiqui',
#  'markjohnlucas',
#  'Vaibhav',
#  'manavchoudhary',
#  'nikolaospapachristou',
#  'jcarlos001',
#  'vslala',
#  'Ngel-Castro',
#  'rilek',
#  'dawei-wang',
#  'George-Petrovski',
#  'JeffUssing',
#  'edstgo',
#  'yxblee',
#  'barisates',
#  'ankkrish',
#  'pratickRoy',
#  'pereirakadu',
#  'justinsamuel92',
#  'dotsnangles',
#  '609151318',
#  'RyanAugust',
#  'igarash1',
#  'dbarrington',
#  'noid11',
#  'ioing',
#  'AruulmozhivarmanS',
#  'Tusharjagi',
#  'ivaylo-yordanov',
#  'rramirez0203',
#  'emullaraj',
#  'mcguegi',
#  'nbhirud',
#  'fischerleon',
#  'UmutSERIFLER',
#  'zhu0823',
#  'Joe192168',
#  'LindaHaviv',
#  'ball582',
#  'dmitrykrisko',
#  'we1l1n',
#  'thangnm93',
#  'dongzhuoyao',
#  'xuelangqingkong',
#  'godobyte',
#  'chanffdavid',
#  'anomaly-88',
#  'CLF3721',
#  'undabah',
#  'aymenbelarbi',
#  'ashish936',
#  'giotramu',
#  '0xlkda',
#  'guilhermebc',
#  'SMBgurus',
#  'mate-h',
#  'artur-sak13',
#  'yorshreynoso',
#  'yehuizhang',
#  'AAdewunmi',
#  'Zenidog8',
#  'aiwongs',
#  'kalsyanpradeep',
#  'charaton',
#  'vonzou',
#  'jaymahfudy',
#  'maxsxu',
#  'keita-hino',
#  'KyuDounSim',
#  'Anirudh257',
#  'jmartins-sh',
#  'satyarajreddy',
#  'AnsonHwang86',
#  'xzm2004260',
#  'anirudhbagri',
#  'STCYC',
#  'rsmelo92',
#  'StrangerCoug',
#  'keren123',
#  'Grimgog',
#  'noodanee',
#  'alobe',
#  'JadeCong',
#  'dancause',
#  'graceko22',
#  'paletode',
#  'Timotej979',
#  'erenaslandev',
#  'serhiiklenachov',
#  'camerondurham',
#  'khanhhuy288',
#  'gstair',
#  'ifbowen',
#  'hotsticker',
#  'ningfc',
#  'RishabhKr97',
#  'jiangoz',
#  'ardasatata',
#  'Murplugg',
#  'tanvirstreame',
#  'kworkbee',
#  'arnab-ray',
#  'yuriykuntsyak',
#  'StarDustTwinkle',
#  'bahadirsahin',
#  'SMSesay',
#  'jamestiotio',
#  'anuj97',
#  'yaelBrown',
#  'motmaytinh',
#  'desaidn',
#  'NoxGamingQC',
#  'aravinthakannan',
#  'lingjiekong',
#  'diohsb',
#  'janviyao',
#  'hijiki51',
#  'mksarge',
#  'pradeepkni382',
#  'rdnasim',
#  'shrinidhibarthur',
#  'StrangeKnowledgeIncresed',
#  'Austin47',
#  'shokriw',
#  'franklin-monreal',
#  'xxh031203',
#  'dororoholic',
#  'lossfunc',
#  'feapaydin',
#  'loumalouomega',
#  'james-sungjae-lee',
#  'garyhtou',
#  'd3v2null',
#  'msweetland',
#  'jrjm1111',
#  'mitutitu16',
#  'ShuhaoZQGG',
#  'akashsathyan',
#  'chrisskhoury',
#  'jeremychauvet',
#  'riturajDas',
#  'Logicus03',
#  'chinchillajared',
#  'isabelchaves',
#  'shikharsaxena98',
#  'flukelaster',
#  'rjuer',
#  'mussieh',
#  'lintsai',
#  'nj1787',
#  'rockychang7',
#  'hanwgyu',
#  'wudangqibujie',
#  'DihanDai',
#  'drewfrost',
#  'MUmarJaved',
#  'contimatteo',
#  'amaankulshreshtha',
#  'hackenbacker',
#  'petronem',
#  'my1795',
#  'Pzoom522',
#  'SpeicherA',
#  'nityansuman',
#  'hahacyd',
#  'wangtiechuan',
#  'lynmison',
#  'anaghkanungo7',
#  'RickyC0626',
#  'WladFrazao',
#  'Ming0217',
#  'caesar-one',
#  'xuepengwei',
#  'Ishanna',
#  'nvspavankalyanch',
#  'JoeRMiller',
#  'devStarscream',
#  'nkn6294live',
#  'FanJups',
#  'ShwetaShivangi',
#  'amwi04',
#  'mnk400',
#  'pd14196',
#  'samirdjelal',
#  'tychodev321',
#  'TheFJS14',
#  'Baleryom',
#  'caitinc',
#  'almokhtarbr',
#  'andreacip',
#  'alexanderafanasov',
#  'duranbe',
#  'thapaashis110',
#  'soccernut',
#  'mdobro1',
#  'royswale',
#  'saneknight',
#  'AnhTrieu',
#  'janmarkuslanger',
#  'morinyan',
#  'gujiacun',
#  'adileone',
#  'BIGChask',
#  'mapjx',
#  'fuhaoma',
#  'DXLZ',
#  'nuffQuantumSayd',
#  'kekemao00',
#  'lamsd',
#  'anuq',
#  'igorasantos',
#  'metaphor0',
#  'iashutoshtiwari',
#  'yaravi',
#  'skippermin',
#  'masakiasami',
#  'huannvttd98',
#  'SantosCristiano',
#  'thatbeautifuldream',
#  'happyqq',
#  'iameduardod',
#  'wuchunfu',
#  'venkate5hgunda',
#  'whuhxb',
#  'ks1990cn',
#  'ronnielutalo',
#  'Samutichev',
#  'jongan69',
#  'nmoisesp',
#  'kayericson',
#  'tjolr',
#  'LuGO0',
#  'lodhik9',
#  'cultivate5253',
#  'elafifi',
#  'akazyti',
#  'boomer2752',
#  'Luccasoli',
#  'benmassaoud',
#  'abheesht17',
#  'ShrivatsAgrawal',
#  'HebaElGalad',
#  'himanshututeja1998',
#  'sevenhqj',
#  'AsadAmir111',
#  'CWHer',
#  'Pei1133',
#  'proKress',
#  'SamuelMaculuve',
#  'pasenchenko',
#  'jinjidong',
#  'eemailme',
#  'Nikronic',
#  'Razdeep',
#  'FenTheDev',
#  'Dxdzy86',
#  'skywalkersPadawan',
#  'patrick22414',
#  '13984468001',
#  'Jiahuan-Pei',
#  'AdityaSoni17',
#  'preciouschydo',
#  'johngunerli',
#  'xmaxance',
#  'akashmdkml',
#  'Menotron',
#  'smustafa75',
#  'nanaboat1',
#  'eshack94',
#  'Karim-53',
#  'EthanC-8',
#  'nitinnbisht',
#  'ericpark123',
#  'Matheus-ESW',
#  'allenduchaoyuan',
#  '5l1v3r1',
#  'Yulv-git',
#  'hexolan',
#  'moqsien',
#  'MilleniumSpark',
#  'sagsango',
#  'Programador89',
#  'robertgro',
#  'JasonMoon95',
#  'raashidanwar',
#  'jackpan123',
#  'bshreddy',
#  'TsukasaSeto',
#  'PallaviVarandani',
#  'alvinlal',
#  'Rookl',
#  'awabasher',
#  'Katsukiniwa',
#  'PMcTwist',
#  'hqng',
#  'rkv0id',
#  'MadeInLondon',
#  'shiminfxcvii',
#  'sigsant',
#  'celikgokhun',
#  'shiva0612',
#  'jk4freedom',
#  'kyamashiro',
#  'LasVegasBilly',
#  'Turbocaspal',
#  'davnunes',
#  'afondiel',
#  'johnnyrtrentin',
#  'stnorbi',
#  'stacyrymer86',
#  'zero-null',
#  'jh9875',
#  'GITWHB',
#  'ricardosuman',
#  'mencarellic',
#  'rabbithophop',
#  'ftf1218',
#  'hirawatt',
#  'adilet-saken',
#  'marcomamprin',
#  'Thejuskbenny',
#  'TomasDavidYe',
#  'nanaxumu',
#  'GabrielFerrante',
#  '13995595007',
#  'tinahuang222',
#  'Bhavuk-Garg',
#  'Mzon2857',
#  'thiagomares',
#  'mjsheikh',
#  'anishamalde',
#  'easy147',
#  'TeddyCom1',
#  'prabhumns',
#  'HyunjunA',
#  'harishravi121',
#  'iamharvey',
#  'rahul-zomato',
#  'ricardopra',
#  'avanishvyas',
#  'inframarauder',
#  'YjqZhouxiao',
#  'adhamsalama',
#  'LuoTailong',
#  'sovansambath-phann',
#  'rkej',
#  'jinshuye',
#  'ibn-khafagah',
#  'kartikeytewari',
#  'md-arfin-cse',
#  'johncruyff14',
#  'johan-lab',
#  'ambanerjee',
#  'bzamith',
#  'deviknitkkr',
#  'Abirul',
#  'ranefattesingh',
#  'nesakobi',
#  'hunghg255',
#  'andrewdge',
#  'RobertConde',
#  'hartl3y94',
#  'saarthdeshpande',
#  'leechenze',
#  'Dexterzprotege',
#  'sandrawilczynski',
#  'ManojTGN',
#  'Debarshi95',
#  'gauharayub',
#  'GowthamSk1',
#  'PolyVoid',
#  'middas-0706',
#  'WendyYanto',
#  'batuhan-basoglu',
#  'sangamesh-kodge',
#  'claudsonbarros',
#  'yotamnahum',
#  'huiminlim',
#  'sumukhteja',
#  'valtab',
#  'JankinTian',
#  'djmcclary',
#  'theroyakash',
#  'sadoreko',
#  'billsenxu',
#  'MarcoSantonastasi',
#  'cheungfujai',
#  'amadsalmon',
#  'infinitepower18',
#  'ashr4f1arr2ad',
#  'rgdyy',
#  'shayanekat',
#  'fellipematos',
#  'Disciple0fMarx',
#  'VE5ETA',
#  'KlinKlinKlin',
#  'ishu-thakur',
#  'brijeshbhalodiya',
#  'zaaakher',
#  'XRLZX8',
#  'soumyadbanik',
#  'zhnzhang',
#  'yhf98',
#  'xjhofernandes',
#  'gauravagrwal',
#  'juanca-jimi',
#  'mapy1874',
#  'JohnDNC',
#  'zeelsheladiya',
#  'ImKunYoung',
#  'EduardHov',
#  'risejl',
#  'Soumil-Bhattacharya',
#  'mahmoudmohamed22',
#  'johnmccants002',
#  'samedsemihs',
#  'moramadan98',
#  'aymandarwish',
#  'HongLouyemeng',
#  'maniac1122',
#  'Sambit650',
#  'haja-fgabriel',
#  'kohring',
#  'okonri',
#  'paulohenz',
#  'leopoldoH',
#  'cnhuz',
#  'liltommy1dev',
#  'Wwillers',
#  'owini',
#  'amirmojarad',
#  'RichardZj',
#  'nolvuscodes',
#  'MarcoSteinke',
#  'acox216',
#  'smy1999',
#  'switcombe',
#  'anujchoudhary-17',
#  'mazrean',
#  'XrosLiang',
#  '994Simone',
#  'matheussooares',
#  'Mystic-77',
#  'bruno-aires',
#  'Jirigesi',
#  'imokhtar',
#  'ArthurAnastopulos',
#  'w3dg',
#  'guilefoylegaurav',
#  'denmj',
#  'frankxzAmazon',
#  'tdweer',
#  'ericwidjaja',
#  'mirfanaslam',
#  'nayeonshin',
#  'xiaozhiob',
#  'u-yas',
#  'smelouah',
#  'icqmula',
#  'dmascheck',
#  'Abhirajnow',
#  'sanjuchandra',
#  'sadiqshaik123',
#  'cccaimingjian',
#  'anurag01a',
#  'masrafi115',
#  'sm-heard',
#  'Abhijrathod',
#  'leonardoknakagawa',
#  'agastaldellomaccomit',
#  'steffiypx',
#  'AdnanAaddi',
#  'MaxDeveloper16',
#  'hchen19',
#  'leonardofhy',
#  'tenpa007',
#  'gtrman97',
#  'MuffinAmor',
#  'amiranbari',
#  'rushilenekar20',
#  'soma2000-lang',
#  'jin-sungdae',
#  'Git-Codder',
#  'Ayush-Pujari-07',
#  'songziqwq',
#  'goillotc',
#  '2019-GitHub-Chu',
#  'Tarsisnbs',
#  'dylenchang',
#  'chinkin707',
#  'frankporco',
#  'adithya1010',
#  'sametcn99',
#  'anubhvshrma18',
#  'Aditya-Khemka',
#  'chanwoo00106',
#  'FrankQixiangGao',
#  'alikemalozgumus',
#  'Codesmaster-lab',
#  'gwd666',
#  'dhanrajswami',
#  'Supriyo8799',
#  'Maher-RJ',
#  'Dajun-2019',
#  'LuanGomes12',
#  'stevenrsewell',
#  'Symon629',
#  'kranti2201',
#  'prad-j',
#  'jaquespavan',
#  'huiyouyou',
#  'vignesh5535',
#  'huai-jie',
#  'bipin0x01',
#  'chrichri17',
#  'GessioMori',
#  'TylerMamrot',
#  'danmslamt',
#  'Pecorari',
#  '1MuhammadFarhanAslam',
#  'br8km',
#  'najmehn00',
#  'Uplift-0508',
#  'ajmalbinnizam',
#  'TatsuyaNakagoshi',
#  'jigordev',
#  'NonymousMorlock',
#  'EfeAcar6431',
#  'akinfelami',
#  'avstreamdevpro',
#  'kqiq',
#  'NaoyaTatetsu',
#  'mijung-in-11st',
#  'simonjgr',
#  'Vigneshkumar212',
#  'avadhutjc',
#  'MLHaddon',
#  'Capital-SetMawHtay',
#  'jcork4real',
#  'samr874',
#  'aditya-repos',
#  'spencerlepine',
#  'calbergs',
#  'yusuke-z',
#  'jimmysmits',
#  'Drag0nf1y',
#  'JohnDoll2023',
#  'Saipraneeth99',
#  'ssantoshp',
#  'vinodpatildev',
#  'leejoonhun',
#  'mmhamdy',
#  'lorenonzi',
#  'VitorAkira-me',
#  'solfonte',
#  'PrideStudio',
#  'CodeMaster719',
#  'Matt-Bulk',
#  'xiao-cy',
#  'galichy79',
#  'thefaheemkhan',
#  'Flaiers',
#  'Derokkk',
#  'Shahna-C',
#  'chosungmann',
#  'Ethan-Ka',
#  'grahamwaters',
#  'deezeddd',
#  'jaymepsantos',
#  'mohamedhabibwork',
#  'hueiwhfa',
#  'anurag1504t',
#  'rajveer43',
#  'Kushan2k',
#  'Thilak-KN',
#  'Tiger15cub',
#  'AesisGit',
#  'rafaelporfiriobarros',
#  'OBud75',
#  'yosefkiros',
#  'benzebra',
#  'HamdanAr',
#  'ralintuscano',
#  'rhattox',
#  'FurkanEdizkan',
#  'SegaGLm',
#  'celso-na-teixeira',
#  'nilesh05apr',
#  'EM51641',
#  'seanpm2001',
#  'thiagodebugs',
#  'dylanhood',
#  'chris0765',
#  'JohnPPinto',
#  'Pquar',
#  'oss-mad',
#  'Mindula-Dilthushan',
#  'AHANCIT',
#  'sebaminaya0',
#  'd-t-n',
#  'rbuchmann77',
#  'Rameshraj55',
#  'SeifEldinMohamed',
#  'SteCC',
#  'JoseRicardoPE',
#  'PhumyJS',
#  'yuyingjun0922',
#  'shakhzodtojiev',
#  'ShabbirHasan1',
#  'klkuoguru',
#  'ggopal13',
#  'angeloS-98',
#  'yagikota',
#  'DougRog',
#  'rdbender',
#  'uivid64',
#  'deevanshu-k',
#  'linquint',
#  'jeanhackpy',
#  'PhaedrusFlow',
#  'nguyen-duy-tan',
#  'Tpeach9474',
#  'KennyOliver',
#  'ronnieangeles',
#  'mahmud0v',
#  'carnate-tech',
#  'mertkilix',
#  'Ghost1386',
#  'asmnajmussakibkhan',
#  'istellaliu',
#  'QuantumBoy1010',
#  'polygonnedpotato',
#  'MadushanNimantha',
#  'Choikyudong',
#  'Harshi-itaSinha',
#  'anthowest',
#  'emiltervo',
#  'gustavoturin',
#  'mohd-salem',
#  'Infisrael',
#  'MateSousa',
#  'marcelozepeunam',
#  'canyoldas0',
#  'erfuun',
#  'madcitymultimedia',
#  'arunavabasucom',
#  'JonathanCristovao',
#  'ugke',
#  'Gustavo-Murdiga88',
#  'uk-2',
#  'Jiyu-Kim',
#  'aadarsh-af',
#  'karthikmurakonda',
#  'fantastic0206',
#  'littlelionly',
#  'thunder-007',
#  'ibarraz5',
#  'vidda5',
#  'AndreiMariciuc',
#  'tatvil',
#  'michelececcacci',
#  'nabeelnoor',
#  'sherlcok314159',
#  'mist1024',
#  'elerner42',
#  'vedantraval2310',
#  'juliana-silva-hub',
#  'mrrushikeshdaund',
#  'sudongyuer',
#  'LlandspitRunzingf',
#  'jianan1104',
#  'Westsi',
#  'AnmolVerma404',
#  'JoseLopezSolis',
#  'Ashish0898',
#  'muratali016',
#  'ozancck',
#  'farinaceos']

# %%
len(seguidores)
# Out:
# 900

# %% [markdown]
# ---

# %% [markdown]
# Para praticar o conteúdo aprendido no decorrer dessa aula e também aprender novos, vamos realizar um desafio prático utilizando a biblioteca Requests e a API do GitHub.
#
# Nossa próxima tarefa é realizar o fork de um repositório da Amazon utilizando uma requisição do tipo POST.
#
# Fazer um fork de um repositório é como criar uma cópia de um projeto que pertence a outra pessoa ou organização dentro do seu próprio perfil no GitHub. Isso permite que você trabalhe em uma versão do projeto sem afetar o original, podendo fazer modificações, correções de bugs e melhorias.
#
# Para realizarmos esse processo, vamos precisar acessar a documentação da API do GitHub onde existem informações sobre como realizar esse processo: Forks - Create a fork.
#
# Após analisar a documentação, é importante não esquecermos de realizar alguns passos:
#
# conferir o endpoint que deve ser utilizado para realização do fork;
# acessar os repositórios públicos da Amazon, selecionar um deles para fazer o fork e salvar seu nome em uma variável;
# enviar o token e a versão da API no momento de fazer a requisição.

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn'
repo = 'supply-chain-simulation-environment'

url = f'{api_base_url}/repos/{owner}/{repo}/forks'
url
# Out:
# 'https://api.github.com/repos/amzn/supply-chain-simulation-environment/forks'

# %%
access_token = 'token removido para commit'
headers = {'Authorization': 'Bearer ' + access_token,
          'X-GitHub-Api-Version': '2022-11-28'}

# %%
# enviando uma requisição POST para realizar o fork
response = requests.post(url, headers=headers)

# conferindo o status code da requisição
print(f"{response.status_code}")
# Out:
# 202
